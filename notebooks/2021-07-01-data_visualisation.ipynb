# %%
# %load_ext watermark
# %watermark -v -n -m -p pandas
# Out:
# Python implementation: CPython
# Python version       : 3.8.10
# IPython version      : 7.25.0
#
# pandas: 1.3.1
#
# Compiler    : GCC 9.3.0
# OS          : Linux
# Release     : 4.15.0-151-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 40
# Architecture: 64bit

# %%
import pandas as pd

# %%
TRAIN_IMAGES = "/data/raw/panda/train_images/"
df = pd.read_csv("/data/raw/panda/train.csv")

# Change negative gleason_score to 0+0
df["gleason_score"] = df["gleason_score"].apply(lambda x: "0+0" if x=="negative" else x)

# %%
table1 = df.groupby(["data_provider", "isup_grade"]).size().reset_index(name="counts")
table1.style.background_gradient(cmap="Purples", vmin=5)
# Out:
# <style type="text/css">
# #T_f0244_row0_col1, #T_f0244_row1_col1, #T_f0244_row2_col1, #T_f0244_row3_col1, #T_f0244_row4_col1, #T_f0244_row5_col1, #T_f0244_row6_col1, #T_f0244_row7_col1, #T_f0244_row8_col1, #T_f0244_row9_col1, #T_f0244_row10_col1, #T_f0244_row11_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_f0244_row0_col2 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_f0244_row1_col2 {
#   background-color: #481185;
#   color: #f1f1f1;
# }
# #T_f0244_row2_col2 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_f0244_row3_col2 {
#   background-color: #e9e8f2;
#   color: #000000;
# }
# #T_f0244_row4_col2 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_f0244_row5_col2 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_f0244_row6_col2 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_f0244_row7_col2 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_f0244_row8_col2 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_f0244_row9_col2 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_f0244_row10_col2 {
#   background-color: #b7b7d9;
#   color: #000000;
# }
# #T_f0244_row11_col2 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f0244_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data_provider</th>
#       <th class="col_heading level0 col1" >isup_grade</th>
#       <th class="col_heading level0 col2" >counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0244_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0244_row0_col0" class="data row0 col0" >karolinska</td>
#       <td id="T_f0244_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f0244_row0_col2" class="data row0 col2" >1925</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0244_row1_col0" class="data row1 col0" >karolinska</td>
#       <td id="T_f0244_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_f0244_row1_col2" class="data row1 col2" >1814</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0244_row2_col0" class="data row2 col0" >karolinska</td>
#       <td id="T_f0244_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_f0244_row2_col2" class="data row2 col2" >668</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0244_row3_col0" class="data row3 col0" >karolinska</td>
#       <td id="T_f0244_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_f0244_row3_col2" class="data row3 col2" >317</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0244_row4_col0" class="data row4 col0" >karolinska</td>
#       <td id="T_f0244_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_f0244_row4_col2" class="data row4 col2" >481</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0244_row5_col0" class="data row5 col0" >karolinska</td>
#       <td id="T_f0244_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_f0244_row5_col2" class="data row5 col2" >251</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0244_row6_col0" class="data row6 col0" >radboud</td>
#       <td id="T_f0244_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f0244_row6_col2" class="data row6 col2" >967</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0244_row7_col0" class="data row7 col0" >radboud</td>
#       <td id="T_f0244_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_f0244_row7_col2" class="data row7 col2" >852</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0244_row8_col0" class="data row8 col0" >radboud</td>
#       <td id="T_f0244_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_f0244_row8_col2" class="data row8 col2" >675</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f0244_row9_col0" class="data row9 col0" >radboud</td>
#       <td id="T_f0244_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_f0244_row9_col2" class="data row9 col2" >925</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f0244_row10_col0" class="data row10 col0" >radboud</td>
#       <td id="T_f0244_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_f0244_row10_col2" class="data row10 col2" >768</td>
#     </tr>
#     <tr>
#       <th id="T_f0244_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f0244_row11_col0" class="data row11 col0" >radboud</td>
#       <td id="T_f0244_row11_col1" class="data row11 col1" >5</td>
#       <td id="T_f0244_row11_col2" class="data row11 col2" >973</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.sample(10)
# Out:
#                                image_id data_provider  isup_grade  \
# 10053  f3273751f723042683d45d00d3880c8c    karolinska           0
# 4494   6eff61540d687bb80f2eda923b2dca9b       radboud           5
# 7222   afa5ed8df00c981e8e4db6ba7799472c    karolinska           1
# 6237   98ba51c7a4ca7316ff1bc776365ca14d       radboud           3
# 9130   dc7825252bd5c07e9a31c0651c989c77       radboud           0
# 9193   de25838fbbd4c64febcac5c2a7c094bc    karolinska           1
# 8242   c6fb997f235db1a874d4e4f208e8e84e    karolinska           0
# 4954   7a40364bb1370598575caac647f1635f    karolinska           0
# 4719   74c2ad4cf2820e6ede00c6c4fb3e4ab2    karolinska           4
# 548    0dccbb58add854759951038d5ee736ab       radboud           1
#
#       gleason_score
# 10053           0+0
# 4494            4+5
# 7222            3+3
# 6237            4+3
# 9130            0+0
# 9193            3+3
# 8242            0+0
# 4954            0+0
# 4719            4+4
# 548             3+3
